# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib as mpl

import seaborn as sns
import geopandas

import os
import time
from matplotlib.cbook import get_sample_data

from PIL import Image, ImageDraw

from matplotlib.cm import cool
from matplotlib.patches import Patch

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path_data=r"/content/drive/MyDrive/Observatorio Fiscal Conjunto/Gasto Público/Finanzas territoriales/Operaciones_Efectivas_Caja/297199ac-9c20-4eae-bb5d-4939ceb36a2c (1).xlsx"
path_geo=r"/content/drive/MyDrive/Observatorio Fiscal Conjunto/Gasto Público/Finanzas territoriales/Operaciones_Efectivas_Caja/mapas"

# %%
data=pd.read_excel(path_data)

# %%
geodata= geopandas.read_file(path_geo, encoding="utf-8")

# %%
data
# Out:
#       Departamento  Código Municipio Nombre Municipio   Año  INGRESOS TOTALES  \
# 0         AMAZONAS             91001          LETICIA  2000       7101.000000
# 1         AMAZONAS             91540    PUERTO NARIÑO  2000       1357.000000
# 2        ANTIOQUIA              5001         MEDELLÍN  2000     630625.000000
# 3        ANTIOQUIA              5002        ABEJORRAL  2000       4453.000000
# 4        ANTIOQUIA              5004         ABRIAQUÍ  2000       1478.000000
# ...            ...               ...              ...   ...               ...
# 24218       VAUPES             97666          TARAIRA  2021      15653.030760
# 24219      VICHADA             99001   PUERTO CARREÑO  2021      36395.664955
# 24220      VICHADA             99524     LA PRIMAVERA  2021      23488.768467
# 24221      VICHADA             99624    SANTA ROSALIA  2021       9328.525500
# 24222      VICHADA             99773         CUMARIBO  2021      69426.056162
#
# ...

# %%
geodata

# %%
geodata["llave"]=geodata["MPIO_CDPMP"].astype(int)

# %%
info=data.merge(geodata, how="left", left_on=["Código Municipio"],right_on='llave')

# %%
geodata.to_excel(r"/content/drive/MyDrive/Observatorio Fiscal Conjunto/Gasto Público/Finanzas territoriales/Operaciones_Efectivas_Caja"+r"/maped.xlsx")
